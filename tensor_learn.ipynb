# %% [markdown]
# <a href="https://colab.research.google.com/github/swatijaiswal10-code/pytorch-tutorial/blob/main/tensor_learn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
